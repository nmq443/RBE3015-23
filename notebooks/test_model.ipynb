# %%
# !pip install ultralytics
# !git clone https://github.com/nmq443/RBE3015-23.git
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 904.3/904.3 kB 22.4 MB/s eta 0:00:00
# ...
# Cloning into 'RBE3015-23'...
# remote: Enumerating objects: 610, done.
# remote: Counting objects: 100% (97/97), done.
# remote: Compressing objects: 100% (68/68), done.
# remote: Total 610 (delta 26), reused 75 (delta 16), pack-reused 513 (from 2)
# Receiving objects: 100% (610/610), 64.21 MiB | 39.23 MiB/s, done.
# Resolving deltas: 100% (74/74), done.

# %%
import os
os.chdir('RBE3015-23/')

# %%
# !git checkout nmq
# Out:
# Branch 'nmq' set up to track remote branch 'nmq' from 'origin'.
# Switched to a new branch 'nmq'

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO('weights/best.pt')

# %%
model.val(save=True)
# Out:
# Ultralytics 8.3.55 🚀 Python-3.10.12 torch-2.4.1+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3,010,328 parameters, 0 gradients, 8.1 GFLOPs
# ...
# 100%|██████████| 755k/755k [00:00<00:00, 39.2MB/s]
# val: Scanning /kaggle/input/pcb-counting-dataset/dip_dataset/valid/labels... 100 images, 0 backgrounds, 0 corrupt: 100%|██████████| 100/100 [00:00<00:00, 149.27it/s]
# val: WARNING ⚠️ Cache directory /kaggle/input/pcb-counting-dataset/dip_dataset/valid is not writeable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:48<00:00,  6.98s/it]
#                    all        100      18902      0.423      0.296      0.323      0.206
#                 Button         12         60      0.495      0.433      0.453      0.376
#       Capacitor Jumper         40       3631      0.169      0.105     0.0731     0.0306
# ...
